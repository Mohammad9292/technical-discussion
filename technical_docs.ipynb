# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammad9292/technical-discussion/blob/main/technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_hyperbolic_function(start=-2, end=2, num_points=100):
    x = np.linspace(start, end, num_points)
    y = np.tanh(x) # Using hyperbolic tangent as an example

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label='tanh(x)', color='blue')
    plt.title('Hyperbolic Tangent Function')
    plt.xlabel('x')
    plt.ylabel('tanh(x)')
    plt.grid(True)
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.legend()
    plt.show()

plot_hyperbolic_function()

# %%
def hello():
  print("hi")
hello()
# Out:
# hi

# %% [markdown]
# ## EDA

# %%
x = 1
print(x)
# Out:
# 1

# %% [markdown]
# ### this is a markdown heading
#
# * one
# * two

# %% [markdown]
# ## Modeling
